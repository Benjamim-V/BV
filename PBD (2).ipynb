# %%
#Criação de Base de dados Mysql
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Float, String

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018"
)

# Create a MySQL cursor
mycursor = mydb.cursor()

try:
    mycursor.execute("CREATE DATABASE IF NOT EXISTS hotel_bookings")
except:
    pass

# Switch to the 'hotel_bookings' database
mycursor.execute("USE hotel_bookings")

print("Database 'hotel_bookings' created successfully!")
# Out:
# Database 'hotel_bookings' created successfully!

# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018"
)

mycursor = mydb.cursor()
mycursor.execute("USE hotel_bookings")

# Create the 'rooms' table
mycursor.execute("""
CREATE TABLE main_info (
    id_reservation INT AUTO_INCREMENT PRIMARY KEY,
    hotel VARCHAR(255),
    lead_time INT,
    arrival_date_year INT,
    arrival_date_month VARCHAR(255),
    arrival_date_week_number INT,
    arrival_date_day_of_month INT,
    country VARCHAR(255),
    market_segment VARCHAR(255),
    distribution_channel VARCHAR(255),
    is_repeated_guest INT,
    booking_changes INT,
    days_in_waiting_list INT,
    company VARCHAR(255),
    customer_type VARCHAR(255),
    reservation_status_date DATE
);

""")

# Create the 'bookings' table
mycursor.execute("""
CREATE TABLE reservas_status (
    id_reservation INT,
    is_canceled INT,
    arrival_date_year INT,
    arrival_date_month VARCHAR(255),
    agent VARCHAR(255),
    previous_cancellations INT,
    previous_bookings_not_canceled INT,
    country VARCHAR(255),
    deposit_type VARCHAR(255),
    reservation_status VARCHAR(255),
    PRIMARY KEY (id_reservation),
    FOREIGN KEY (id_reservation) REFERENCES Main_Info(id_reservation)
);

""")

# Create the 'guests' table
mycursor.execute("""
CREATE TABLE stays_info (
    id_reservation INT,
    stays_in_week_nights INT,
    stays_in_weekend_nights INT,
    adults INT,
    children INT,
    babies INT,
    required_car_parking_spaces INT,
    meal VARCHAR(255),
    reserved_room_type VARCHAR(255),
    total_of_special_requests INT,
    PRIMARY KEY (id_reservation),
    FOREIGN KEY (id_reservation) REFERENCES Main_Info(id_reservation)
);

""")

# Commit the changes to the database
mydb.commit()
print("Database 'Table main_rnfo, reservas_status, stays_info ' created successfully!")
# Close the connection to the database
mydb.close()
# Out:
# Database 'Table main_rnfo, reservas_status, stays_info ' created successfully!

# %%
#Insert de dados no mysql usando o ficheiro csv 
# Insert de dados no MySQL usando o ficheiro CSV 
import pandas as pd
import time
from sqlalchemy import create_engine

# Carrega os dados CSV em DataFrames
df1 = pd.read_csv('C:\\Users\\mamus\\OneDrive\\Ambiente de Trabalho\\MScFCUL\\BasedeDasosAvan\\project\\Tabela1.csv')
df2 = pd.read_csv('C:\\Users\\mamus\\OneDrive\\Ambiente de Trabalho\\MScFCUL\\BasedeDasosAvan\\project\\Tabela2.csv')
df3 = pd.read_csv('C:\\Users\\mamus\\OneDrive\\Ambiente de Trabalho\\MScFCUL\\BasedeDasosAvan\\project\\Tabela3.csv')

# Estabeleça uma conexão com o banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# Medir o tempo de execução
start_time = time.time()

# Inserir dados na base de dados
try:
    with engine.begin() as connection:
        df1.to_sql('main_info', con=connection, if_exists='append', index=False)
        df2.to_sql('reservas_status', con=connection, if_exists='append', index=False)
        df3.to_sql('stays_info', con=connection, if_exists='append', index=False)
        
    # if_exists: Este parâmetro determina o que fazer se a tabela já existir no banco de dados.
    # 'fail': Gera um ValueError se a tabela existir.
    # 'replace': Substitui a tabela existente se ela já existir.
    # 'append': Adiciona os novos dados à tabela existente.

    end_time = time.time()
    execution_time = end_time - start_time
    
    print(f"Dados inseridos com exito. Tempo de execução: {execution_time:.2f} segundos.")

# Exibir o erro caso a inserção falhar
except Exception as e:
    print(f"Error: {e}")
# Out:
# Dados inseridos com exito. Tempo de execução: 62.35 segundos.

# %%
#Consulta simples
#Quais são os país que tiveram resevas superior a 1000 e, em que ano e mes que isto aconteceu e o hotel que mais requições teve?
#R:
import time
import pandas as pd
from sqlalchemy import create_engine

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# Registre o tempo de início
start_time = time.time()

# Consulta SQL corrigida
sql_consulta = """
    SELECT
        hotel,
        country,
        arrival_date_year AS arrival_year,
        arrival_date_month AS arrival_month,
        COUNT(*) AS total_reservas
    FROM
        main_info 
    GROUP BY
        hotel, country, arrival_date_year, arrival_date_month
    HAVING
        COUNT(*) > 1000
    ORDER BY
        total_reservas DESC
"""

# Registre o tempo de fim


# Execute a consulta e armazene o resultado em um DataFrame
df_sql = pd.read_sql(sql_consulta, con=engine)
end_time = time.time()
execution_time = end_time - start_time
# Exiba o DataFrame resultante
print(df_sql)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
#             hotel country  arrival_year arrival_month  total_reservas
# 0   Hotel 7 Seven     PRT          2015     September            2293
# 1   Hotel 7 Seven     PRT          2015       October            2206
# 2   Hotel 7 Seven     PRT          2016          June            1897
# 3   Hotel 7 Seven     PRT          2017           May            1552
# 4   Hotel 7 Seven     PRT          2015        August            1548
# 5   Hotel 7 Seven     PRT          2016           May            1531
# 6   Hotel 7 Seven     PRT          2016       October            1435
# 7   Hotel 7 Seven     PRT          2016         April            1426
# 8   Hotel 7 Seven     PRT          2016     September            1350
# 9   Hotel 7 Seven     PRT          2017          June            1341
# 10  Hotel 7 Seven     PRT          2015          July            1300
# 11  Hotel 7 Seven     PRT          2016      November            1200
# 12  Hotel 7 Seven     PRT          2016      February            1136
# 13  Hotel 7 Seven     PRT          2017         April            1132
# 14  Hotel 7 Seven     PRT          2016         March            1114
# 15  Hotel 7 Seven     PRT          2017         March            1006
# Tempo de execução: 3.37 segundos.

# %%
#Consulta simples
#Quais são os país que tiveram resevas alteradas suerior a 100 e, em que ano isto ocorreu? 
#R:
start_time = time.time()
sqlConsult = """
    SELECT
    arrival_date_year,
    country,
    COUNT(*) AS total_reservas_alteradas
FROM
    main_info
WHERE
    booking_changes = 0 
GROUP BY
    arrival_date_year, country
HAVING
    COUNT(*) > 90
ORDER BY
    arrival_date_year;
"""
#A cláusula HAVING é usada em combinação com GROUP BY para filtrar os resultados de uma agregação com base a contagem das reservas.
#Neste caso, estamos filtrando os resultados para incluir apenas as linhas onde o total de reservas é maior que 100.
# Execute a consulta e armazene o resultado em um DataFrame
dfSql = pd.read_sql(sqlConsult, con=engine)
end_time = time.time()
execution_time = end_time - start_time
#Estas linhas, permitem remover o numero total de linhas e colunas a serem exibidas 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Exiba o DataFrame resultante
print(dfSql)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
#     arrival_date_year country  total_reservas_alteradas
# 0                2015    None                       110
# 1                2015     BEL                       172
# 2                2015     BRA                       123
# 3                2015     CHE                       107
# 4                2015      CN                       112
# 5                2015     DEU                       459
# 6                2015     ESP                      1634
# 7                2015     FRA                      1126
# 8                2015     GBR                      1136
# 9                2015     IRL                       436
# 10               2015     ISR                       108
# 11               2015     ITA                       432
# 12               2015     NLD                       161
# 13               2015     PRT                     11811
# 14               2015     SWE                       113
# 15               2015     USA                       140
# 16               2016    None                       224
# 17               2016     AGO                       153
# 18               2016     ARG                        93
# 19               2016     AUS                       147
# 20               2016     AUT                       544
# 21               2016     BEL                       960
# 22               2016     BRA                       868
# 23               2016     CHE                       714
# 24               2016     CHN                       465
# 25               2016      CN                       439
# 26               2016     DEU                      3226
# 27               2016     DNK                       150
# 28               2016     ESP                      3331
# 29               2016     FIN                       206
# 30               2016     FRA                      4432
# 31               2016     GBR                      4368
# 32               2016     HUN                        92
# 33               2016     IRL                      1230
# 34               2016     ISR                       229
# 35               2016     ITA                      1572
# 36               2016     LUX                       109
# 37               2016     MAR                       106
# 38               2016     NLD                       905
# 39               2016     NOR                       222
# 40               2016     POL                       426
# 41               2016     PRT                     19613
# 42               2016     ROU                       202
# 43               2016     RUS                       205
# 44               2016     SWE                       413
# 45               2016     TUR                       132
# 46               2016     USA                       767
# 47               2017     AGO                        97
# 48               2017     AUS                       191
# 49               2017     AUT                       406
# 50               2017     BEL                       870
# 51               2017     BRA                       851
# 52               2017     CHE                       637
# 53               2017     CHN                       382
# 54               2017      CN                       541
# 55               2017     DEU                      2366
# 56               2017     DNK                       176
# 57               2017     ESP                      2152
# 58               2017     FIN                       131
# 59               2017     FRA                      3285
# 60               2017     GBR                      4360
# 61               2017     IRL                      1163
# 62               2017     ISR                       223
# 63               2017     ITA                      1110
# 64               2017     LUX                       113
# 65               2017     NLD                       662
# 66               2017     NOR                       255
# 67               2017     POL                       239
# 68               2017     PRT                     11182
# 69               2017     ROU                       165
# 70               2017     RUS                       229
# 71               2017     SWE                       314
# 72               2017     USA                       752
# Tempo de execução: 2.72 segundos.

# %%
# Duas consultas complexas, usando junções e agregações, envolvendo pelo menos
#(1) Esta consulta de agregação calcula a média do número de estadias na tabela

import pandas as pd
from sqlalchemy import create_engine
import time

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# (1) Consulta com junção e agregação
#Qual é a média do numero total de pedidos para estadias em cada hotel?
#O resultado final da consulta será uma lista de hotéis acompanhada da média do número total de pedidos especiais para estadias em cada hotel.
#Isso fornece uma visão estatística sobre os pedidos especiais médios para diferentes hotéis.
start_time = time.time()
sql_agregacao = """
    SELECT main_info.hotel, AVG(stays_info.total_of_special_requests) as media_stays_total
    FROM main_info
    INNER JOIN stays_info ON main_info.id_reservation = stays_info.id_reservation
    GROUP BY main_info.hotel
"""
# Execute a consulta e armazene o resultado em um DataFrame
df_agregacao = pd.read_sql(sql_agregacao, con=engine)
end_time = time.time()
execution_time = end_time - start_time

# Exiba o resultado do DataFrame
print(df_agregacao)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
#            hotel  media_stays_total
# 0   Resort Hotel             0.6198
# 1  Hotel 7 Seven             0.5469
# Tempo de execução: 5.07 segundos.

# %%
# Duas consultas complexas, usando junções e agregações, envolvendo pelo menos
#(1) Esta consulta de agregação calcula a média do número de estadias na tabela

import pandas as pd
from sqlalchemy import create_engine
import time

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')
# (2) Consulta com junção, filtro e agregação
#Quais são os paises cujo as reservas não foram canceladas?
#o resultado final da consulta será uma lista de países acompanhada do número total de reservas não canceladas para cada país. 
#Isso fornece uma visão estatística sobre a distribuição de reservas não canceladas em diferentes países.
start_time = time.time()
sql_rn_canceladas = """
    SELECT main_info.country, COUNT(*) as total_reservas_canceladas
    FROM main_info
    INNER JOIN reservas_status ON main_info.id_reservation = reservas_status.id_reservation
    WHERE reservas_status.is_canceled = 0
    GROUP BY main_info.country
"""
# Execute a consulta e armazene o resultado em um DataFrame
df_rnc = pd.read_sql(sql_rn_canceladas, con=engine)
end_time = time.time()
execution_time = end_time - start_time

# Exiba o DataFrame resultante
print(df_rnc)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
#     country  total_reservas_canceladas
# 0       PRT                      21071
# 1       GBR                       9676
# 2       USA                       1596
# 3       ESP                       6391
# 4       IRL                       2543
# 5       FRA                       8481
# 6      None                        421
# 7       ROU                        366
# 8       NOR                        426
# 9       OMN                         14
# 10      ARG                        160
# 11      POL                        704
# 12      DEU                       6069
# 13      BEL                       1868
# 14      CHE                       1302
# 15       CN                       1025
# 16      GRC                         93
# 17      ITA                       2433
# 18      NLD                       1717
# 19      DNK                        326
# 20      RUS                        393
# 21      SWE                        797
# 22      AUS                        319
# 23      EST                         65
# 24      CZE                        134
# 25      BRA                       1394
# 26      FIN                        378
# 27      MOZ                         48
# 28      BWA                          1
# 29      LUX                        178
# 30      SVN                         42
# 31      ALB                         10
# 32      IND                        117
# 33      CHN                        537
# 34      MEX                         75
# 35      MAR                        150
# 36      UKR                         48
# 37      SMR                          1
# 38      LVA                         46
# 39      PRI                         10
# 40      SRB                         98
# 41      CHL                         49
# 42      AUT                       1033
# 43      BLR                         17
# 44      LTU                         74
# 45      TUR                        146
# 46      ZAF                         49
# 47      AGO                        157
# 48      ISR                        500
# 49      CYM                          1
# 50      ZMB                          1
# 51      CPV                         12
# 52      ZWE                          2
# 53      DZA                         82
# 54      KOR                         78
# 55      CRI                         18
# 56      HUN                        153
# 57      JAM                          6
# 58      HRV                         75
# 59      IRN                         60
# 60      CAF                          5
# 61      CYP                         40
# 62      NZL                         68
# 63      IDN                         11
# 64      KAZ                         14
# 65      THA                         41
# 66      COL                         48
# 67      DOM                          6
# 68      MKD                          8
# 69      MYS                         25
# 70      NGA                         13
# 71      VEN                         14
# 72      GIB                          7
# 73      ARM                          6
# 74      JPN                        169
# 75      LKA                          7
# 76      CUB                          8
# 77      CMR                         10
# 78      BIH                         10
# 79      MUS                          6
# 80      COM                          2
# 81      SUR                          5
# 82      UGA                          2
# 83      BGR                         63
# 84      CIV                          4
# 85      JOR                         18
# 86      SYR                          3
# 87      PHL                         15
# 88      SGP                         23
# 89      BDI                          1
# 90      URY                         23
# 91      SAU                         15
# 92      KWT                         10
# 93      LBN                         22
# 94      AND                          2
# 95      VNM                          6
# 96      AZE                          8
# 97      PLW                          1
# 98      ARE                          8
# 99      QAT                          4
# 100     EGY                         21
# 101     PER                         23
# 102     SVK                         41
# 103     MDV                          3
# 104     MLT                         13
# 105     MWI                          2
# 106     ECU                         19
# 107     MDG                          1
# 108     ISL                         53
# 109     UZB                          2
# 110     NPL                          1
# 111     BHS                          1
# 112     PAK                          5
# 113     MAC                          1
# 114     TGO                          2
# 115     TWN                         37
# 116     HKG                          3
# 117     DJI                          1
# 118     GEO                          7
# 119     TUN                         20
# 120     STP                          2
# 121     SEN                          3
# 122     KNA                          2
# 123     ETH                          2
# 124     IRQ                         14
# 125     RWA                          2
# 126     LIE                          2
# 127     MMR                          1
# 128     PAN                          9
# 129     TMP                          2
# 130     BFA                          1
# 131     KEN                          4
# 132     MCO                          3
# 133     LBY                          8
# 134     GNB                          8
# 135     TZA                          2
# 136     MLI                          1
# 137     BGD                          3
# 138     BHR                          1
# 139     NAM                          1
# 140     BOL                         10
# 141     SYC                          1
# 142     PRY                          4
# 143     BRB                          4
# 144     ABW                          2
# 145     AIA                          1
# 146     SLV                          2
# 147     DMA                          1
# 148     GAB                          2
# 149     PYF                          1
# 150     GUY                          1
# 151     LCA                          1
# 152     ATA                          2
# 153     MNE                          3
# 154     GTM                          4
# 155     GHA                          2
# 156     ASM                          1
# 157     MRT                          1
# 158     NCL                          1
# 159     KIR                          1
# 160     SDN                          1
# 161     ATF                          1
# 162     TJK                          1
# 163     SLE                          1
# 164     LAO                          2
# 165     FRO                          1
# Tempo de execução: 3.14 segundos.

# %%
# ATUALIZAÇÃO DE DADOS mysql
import pandas as pd
from sqlalchemy import create_engine, text
import time

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# Novo valor para a coluna hotel
novo_hotel = "City Hotel"
start_time = time.time()
# Consulta de atualização
sql_update = text(f"""
    UPDATE main_info
    SET hotel = :novo_hotel
    WHERE hotel = "7 Hotel"
""")

# Execute a consulta de atualização
with engine.begin() as connection:
    connection.execute(sql_update, {"novo_hotel": novo_hotel})
end_time = time.time()
execution_time = end_time - start_time
print("Atualização concluída com sucesso.")
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
# Atualização concluída com sucesso.
# Tempo de execução: 2.23 segundos.

# %%
#Inserção de dados manualmente no mysql
import time
import mysql.connector
import pandas as pd

# Estabeleça uma conexão com o banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')
start_time = time.time()
# Crie um DataFrame de exemplo para ilustrar o processo de inserção
# Substitua esta parte do código com o seu DataFrame real
data = {
    'hotel': ['Hotel Rossana'],
    'lead_time': [120],
    'arrival_date_year': [2023],
    'arrival_date_month': ['November'],
    'arrival_date_week_number': [22],
    'arrival_date_day_of_month': ['2023-11-22'],
    'country': ['Angola'],
    'market_segment': ['Direct'],
    'distribution_channel': ['Direct'],
    'is_repeated_guest': [0],
    'booking_changes': [0],
    'days_in_waiting_list': [0],
    'company': [None],
    'customer_type': ['Transient'],
    'reservation_status_date': ['2022-10-20']
}

df = pd.DataFrame(data)

# Inserção de dados na tabela 'Main_Info' usando SQLAlchemy
df.to_sql('main_info', con=engine, if_exists='append', index=False)
end_time = time.time()
execution_time = end_time - start_time
print("Inserção concluída com sucesso.")
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
# Inserção concluída com sucesso.
# Tempo de execução: 0.04 segundos.

# %%
#4-CRIAÇÃO DE INDICES NO MYSQL
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018",
    database="hotel_bookings"
)

mycursor = mydb.cursor()

# Índice para a tabela Main_Info
mycursor.execute("CREATE INDEX idx_id_reservation_main ON main_info(id_reservation)")

# Índice para a tabela Reservas_Status
mycursor.execute("CREATE INDEX idx_id_reservation_reservas ON reservas_status(id_reservation)")

# Índice para a tabela Stays_Info
mycursor.execute("CREATE INDEX idx_id_reservation_stays ON stays_info(id_reservation)")

# Confirmar as alterações no banco de dados
mydb.commit()
print("Índices criados com sucesso!")

# Fechar a conexão com o banco de dados
mydb.close()

# %%
#Criação da base de dados e collections índices no MongoDB
import pymongo
from pymongo import MongoClient
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship
from pymongo.errors import DuplicateKeyError

# Connect to MongoDB
client = MongoClient('localhost', 27017)
db = client.hotel_bookings

# Define the Main_Info collection
main_info = db['main_info']

# Criar um índice único em 'campo_unico' na coleção 'Main_Info'
main_info.create_index([("id_reservation", pymongo.ASCENDING)], unique=True)

# Define the Reservas_Status collection
reservas_status = db['reservas_status']

# Criar índices únicos em 'campo_unico_1' e 'campo_unico_2' na coleção 'Reservas_Status'
reservas_status.create_index([("id_reservation", pymongo.ASCENDING)], unique=True)

# Define the Stays_Info collection
stays_info = db['stays_info']

# Criar um índice único em 'campo_unico' na coleção 'Stays_Info'
stays_info.create_index([("id_reservation", pymongo.ASCENDING)], unique=True)

print("Coleções criadas com sucesso e índices únicos aplicados!")
# Out:
# Coleções criadas com sucesso e índices únicos aplicados!

# %%
import pandas as pd
import pymongo
from pymongo.errors import DuplicateKeyError
import uuid
import time

# Estabeleça uma conexão com o MongoDB
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = client['hotel_bookings']

# Função para gerar ID de reserva
def generate_id_reservation():
    return str(uuid.uuid4())

# Leitura dos arquivos CSV
main_info = 'Tabela1.csv'
reservas_stays = 'Tabela2.csv'
stays_info = 'Tabela3.csv'
df1 = pd.read_csv(main_info)
df2 = pd.read_csv(reservas_stays)
df3 = pd.read_csv(stays_info)

# Inserção dos dados na Tabela1
documents_tabela1 = []
start_time = time.time()
for index, row in df1.iterrows():
    id_reservation = generate_id_reservation()
    main_info_data = {
        "id_reservation": id_reservation,
        "hotel": row['hotel'],
        "lead_time": row['lead_time'],
        "arrival_date_year": row['arrival_date_year'],
        "arrival_date_month": row['arrival_date_month'],
        "arrival_date_week_number": row['arrival_date_week_number'],
        "arrival_date_day_of_month": row['arrival_date_day_of_month'],
        "country": row['country'],
        "market_segment": row['market_segment'],
        "distribution_channel": row['distribution_channel'],
        "is_repeated_guest": row['is_repeated_guest'],
        "booking_changes": row['booking_changes'],
        "days_in_waiting_list": row['days_in_waiting_list'],
        "company": row['company'],
        "customer_type": row['customer_type'],
        "reservation_status_date": row['reservation_status_date'],
    }
    documents_tabela1.append(main_info_data)

try:
    db.main_info.insert_many(documents_tabela1)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f"Data for Tabela1 inserted successfully. Tempo de execução: {execution_time:.2f} segundos.")
except DuplicateKeyError:
    print("Duplicate key error in Tabela1. Skipping insertion.")

# Repita a estrutura para Tabela2
documents_tabela2 = []
start_time = time.time()
for index, row in df2.iterrows():
    id_reservation = generate_id_reservation()
    reservation_status_data = {
         "id_reservation": id_reservation,
        "is_canceled": row['is_canceled'],
        "arrival_date_year": row['arrival_date_year'],
        "arrival_date_month": row['arrival_date_month'],
        "agent": row['agent'],
        "previous_cancellations": row['previous_cancellations'],
        "previous_bookings_not_canceled": row['previous_bookings_not_canceled'],
        "country": row['country'],
        "deposit_type": row['deposit_type'],
        "reservation_status": row['reservation_status'],
    }
    documents_tabela2.append(reservation_status_data)

try:
    db.reservas_status.insert_many(documents_tabela2)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f"Data for Tabela2 inserted successfully. Tempo de execução: {execution_time:.2f} segundos.")
except DuplicateKeyError:
    print("Duplicate key error in Tabela2. Skipping insertion.")

# Repita a estrutura para Tabela3
documents_tabela3 = []
start_time = time.time()
for index, row in df3.iterrows():
    id_reservation = generate_id_reservation()
    stays_info_data = {
        "id_reservation": id_reservation,
        "stays_in_week_nights": row['stays_in_week_nights'],
        "stays_in_weekend_nights": row['stays_in_weekend_nights'],
        "adults": row['adults'],
        "children": row['children'],
        "babies": row['babies'],
        "required_car_parking_spaces": row['required_car_parking_spaces'],
        "meal": row['meal'],
        "reserved_room_type": row['reserved_room_type'],
        "total_of_special_requests": row['total_of_special_requests'],
    }
    documents_tabela3.append(stays_info_data)

try:
    db.stays_info.insert_many(documents_tabela3)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f"Data for Tabela3 inserted successfully. Tempo de execução: {execution_time:.2f} segundos.")
except DuplicateKeyError:
    print("Duplicate key error in Tabela3. Skipping insertion.")

print("Data insertion completed.")
# Out:
# Data for Tabela1 inserted successfully. Tempo de execução: 39.99 segundos.
# Data for Tabela2 inserted successfully. Tempo de execução: 34.00 segundos.
# Data for Tabela3 inserted successfully. Tempo de execução: 34.27 segundos.
# Data insertion completed.

# %%
#Duas consultas simples, selecionando dados de uma ou duas colunas/campos (3)
import pymongo
from pprint import pprint  # Importe a função pprint corretamente

# (1) - Consulta em Main_Info
# Consulta para selecionar dados da coluna 'hotel' em Main_Info

# Substitua 'reservas_status' por 'main_info'
my_collection = db['main_info']
myquery = {'arrival_date_month': 'April', 'country': 'GBR', 'arrival_date_year': 2016}
mydoc = my_collection.find(myquery)

# Verificar se a consulta retornou algum resultado
if my_collection.count_documents(myquery) > 0:
    for doc in mydoc:
        pprint(doc)
else:
    print("Não há documentos para serem exibidos em Main_Info.")

# (2) - Consulta em Reservas_Status
# Consulta para selecionar dados das colunas 'id_reservation' e 'is_cancelled' em Reservas_Status
# Substitua 'Tabela2' por 'reservas_status'
reservas_status = db['Tabela2']
MDB_reservas_status = reservas_status.find({}, {"id_reservation": 1, "is_canceled": 1})

# Verificar se a consulta retornou algum resultado
if reservas_status.count_documents({}) > 0:
    # Display the results of the query
    for resultReservas in MDB_reservas_status:
        pprint(resultReservas)
else:
    print("Não há documentos para serem exibidos em Reservas_Status.")
# Out:
# {'_id': ObjectId('65686082d8f4d4f7789fa166'),
#  'arrival_date_day_of_month': 1,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': 223.0,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '15efd810-78e1-47bd-9eaa-305e2f03ecdf',
#  'is_repeated_guest': 0,
#  'lead_time': 0,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-03'}
# {'_id': ObjectId('65686082d8f4d4f7789fa167'),
#  'arrival_date_day_of_month': 1,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '7fc1cbbe-17a8-4616-aaa2-614d0ab43279',
#  'is_repeated_guest': 0,
#  'lead_time': 144,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-05'}
# {'_id': ObjectId('65686082d8f4d4f7789fa169'),
#  'arrival_date_day_of_month': 1,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'fc5adce7-6867-4519-bc66-875862573fb2',
#  'is_repeated_guest': 0,
#  'lead_time': 144,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-05'}
# {'_id': ObjectId('65686082d8f4d4f7789fa16f'),
#  'arrival_date_day_of_month': 2,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '66a8aa36-ac2d-4936-952a-7fab1706f40c',
#  'is_repeated_guest': 0,
#  'lead_time': 222,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-09'}
# {'_id': ObjectId('65686082d8f4d4f7789fa171'),
#  'arrival_date_day_of_month': 2,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'ac9dc472-3eee-486b-968f-43e4071847d5',
#  'is_repeated_guest': 0,
#  'lead_time': 222,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-09'}
# {'_id': ObjectId('65686082d8f4d4f7789fa173'),
#  'arrival_date_day_of_month': 3,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '16bd841e-d5e6-4df8-ade6-e1e2d61b49dc',
#  'is_repeated_guest': 0,
#  'lead_time': 0,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-05'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1a8'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '0a3219e8-cfb9-4274-a600-dd52d8151113',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1a9'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'b4da0854-27d1-457a-bf0d-68cd7fe4cfc4',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1aa'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '454a0a01-4f47-4a5a-a5ef-17575fff292f',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ab'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '967452e6-1009-4a1a-bd66-578eea073850',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ac'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '6a9a5b7d-b1c7-434f-abae-e42122995db3',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ad'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '54d0482d-0679-4f4d-8503-216da196073d',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ae'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '23ecbc02-c4cc-4b30-9e13-2838633b18d7',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1b1'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'b832cf75-d409-4c48-bbc7-80c4086e761e',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1b2'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '815da39a-942a-44b2-8cbb-3124cd6e8cd3',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1b3'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '2c91cf11-32ea-489b-9a03-fa27c32b5a25',
#  'is_repeated_guest': 0,
#  'lead_time': 116,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1b8'),
#  'arrival_date_day_of_month': 5,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '691807ed-7268-40e6-9c3e-9fb1f8579e5f',
#  'is_repeated_guest': 0,
#  'lead_time': 200,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-12'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1b9'),
#  'arrival_date_day_of_month': 5,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '92742ba5-af6d-4285-b068-1c27374f32c3',
#  'is_repeated_guest': 0,
#  'lead_time': 200,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-12'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1c9'),
#  'arrival_date_day_of_month': 7,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'c41c7c17-a1b9-49ff-bc0e-f04068be4f58',
#  'is_repeated_guest': 0,
#  'lead_time': 23,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-03-16'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e0'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '42615347-ef90-45f2-8d66-7295c8b54eca',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e1'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '24906a1e-7e25-476f-ba2f-5b440a182012',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e2'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'fef503ae-39ad-4bdb-b962-28c89be5fac9',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e3'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'b14175dd-c08f-4e6c-a1bd-486edc9d2f18',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e5'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '22789785-fa49-4132-aa9c-152d0685e50c',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e6'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '5da90db5-7232-4d14-89e7-cc58160f0be7',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e7'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '333089ff-b2da-49cb-959f-56cfc3879698',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e8'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '94f9363d-f829-4fce-aa88-dee352be7fd5',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1e9'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'a0da6a44-050a-4c06-8ea9-1ac0084c7f72',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ea'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '9f912013-48df-4369-8ed9-5bda5ca60fb5',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1eb'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '39bb6443-75a9-41bd-81cc-d8306ca903a9',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ec'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'fee2144e-362e-4389-b89c-e0787b7d2979',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ed'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '7566b3db-ebd6-4c1c-91d5-571cf71e0def',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ee'),
#  'arrival_date_day_of_month': 9,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '8a94328f-bbf8-4344-8553-545c28f6dccd',
#  'is_repeated_guest': 0,
#  'lead_time': 121,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f3'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'f1437712-7163-4a92-81db-4f00b651cc2c',
#  'is_repeated_guest': 0,
#  'lead_time': 190,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f4'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '823d4881-acdf-4dd9-ae2c-ea9cc372ec2d',
#  'is_repeated_guest': 0,
#  'lead_time': 190,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f5'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '84a1b665-d651-4183-bdde-8292be4f435c',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f6'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '4cd24e0f-1040-4d5d-ae91-8465bd6c12f5',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f7'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'f00f107a-1c1d-49ad-95f5-a1837bb3b293',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f8'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '18f73e45-8f39-4fae-b731-a96758d6f48e',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1f9'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'fb7b6509-9f5c-432d-884e-d215aa64680d',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1fa'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'a8d1c825-1e15-4642-a39a-120f3d08fa1e',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1fc'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '9c0d98b5-ad58-4c88-8e60-44e9dc0a2300',
#  'is_repeated_guest': 0,
#  'lead_time': 190,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1fd'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'c44db25a-c63d-4d4b-a381-55e5e227859d',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1fe'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '73f7be90-022b-442e-bab5-b0e8f7620fb8',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa1ff'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '5a84b781-f477-453e-9c79-dea5df8d6882',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa200'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '7641f778-babc-47f6-abe4-17de1df2c781',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa201'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'd2201cfb-c8f2-4e3c-a77c-9bff139e86b5',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa202'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '297054fc-31b3-4df3-b6e8-839603afa5f0',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa203'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'a7a92be0-2de6-438a-b2cc-2a218ebc2dc4',
#  'is_repeated_guest': 0,
#  'lead_time': 190,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa204'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'f5aced17-dc13-4b95-86b7-b8012e9aae83',
#  'is_repeated_guest': 0,
#  'lead_time': 190,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa205'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '5ca570c0-caff-4c24-bc15-0281937081bd',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-01-14'}
# {'_id': ObjectId('65686082d8f4d4f7789fa206'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 4,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '333c859e-793d-4a63-84c5-58747f4522e2',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa207'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 6,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '1fe28089-d719-46fc-ba10-c6516b117761',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-27'}
# {'_id': ObjectId('65686082d8f4d4f7789fa208'),
#  'arrival_date_day_of_month': 10,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '69e598db-4270-44bf-9a2e-2c604d7f6be7',
#  'is_repeated_guest': 0,
#  'lead_time': 275,
#  'market_segment': 'Groups',
#  'reservation_status_date': '2016-04-17'}
# {'_id': ObjectId('65686082d8f4d4f7789fa221'),
#  'arrival_date_day_of_month': 11,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '2ce78c37-05b1-422e-9c30-b8b5f66d6b3d',
#  'is_repeated_guest': 0,
#  'lead_time': 38,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-03-22'}
# {'_id': ObjectId('65686082d8f4d4f7789fa22b'),
#  'arrival_date_day_of_month': 11,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'e72ee556-40c9-490c-bc5e-68423c29c1dd',
#  'is_repeated_guest': 0,
#  'lead_time': 187,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-21'}
# {'_id': ObjectId('65686082d8f4d4f7789fa286'),
#  'arrival_date_day_of_month': 16,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 16,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'dd4c0f29-93f7-4301-bb66-defcaff396a1',
#  'is_repeated_guest': 0,
#  'lead_time': 192,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-23'}
# {'_id': ObjectId('65686082d8f4d4f7789fa28b'),
#  'arrival_date_day_of_month': 17,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '0cbab397-8d11-4af8-aaea-1ce02b31f4c3',
#  'is_repeated_guest': 0,
#  'lead_time': 218,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-04-20'}
# {'_id': ObjectId('65686082d8f4d4f7789fa2c0'),
#  'arrival_date_day_of_month': 18,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'f62e8d61-aca8-4106-9b61-49019dd72ad7',
#  'is_repeated_guest': 0,
#  'lead_time': 172,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-26'}
# {'_id': ObjectId('65686082d8f4d4f7789fa2c1'),
#  'arrival_date_day_of_month': 18,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '9cb8a901-af62-4d40-a0ab-0c8b75c16d60',
#  'is_repeated_guest': 0,
#  'lead_time': 172,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-26'}
# {'_id': ObjectId('65686082d8f4d4f7789fa2c2'),
#  'arrival_date_day_of_month': 18,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '9724ccdf-0530-44e1-af46-9d08f2bd59a3',
#  'is_repeated_guest': 0,
#  'lead_time': 172,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-26'}
# {'_id': ObjectId('65686082d8f4d4f7789fa2c3'),
#  'arrival_date_day_of_month': 18,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'f93bec99-ca93-4c7e-94f2-264730afecbb',
#  'is_repeated_guest': 0,
#  'lead_time': 172,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-26'}
# {'_id': ObjectId('65686082d8f4d4f7789fa2c5'),
#  'arrival_date_day_of_month': 18,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '74b69cd5-4366-402e-bb04-ce6c774aa504',
#  'is_repeated_guest': 0,
#  'lead_time': 172,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-26'}
# {'_id': ObjectId('65686082d8f4d4f7789fa2f4'),
#  'arrival_date_day_of_month': 21,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'adb69dc2-e896-4ef0-a1e0-d61217f0599c',
#  'is_repeated_guest': 0,
#  'lead_time': 168,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-28'}
# {'_id': ObjectId('65686082d8f4d4f7789fa336'),
#  'arrival_date_day_of_month': 23,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '066027d9-9e11-421f-b109-3f4f29800ca1',
#  'is_repeated_guest': 0,
#  'lead_time': 17,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-06'}
# {'_id': ObjectId('65686082d8f4d4f7789fa360'),
#  'arrival_date_day_of_month': 24,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'f07f8eb5-5658-4930-8e90-4dafd8acbf2b',
#  'is_repeated_guest': 0,
#  'lead_time': 167,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-01'}
# {'_id': ObjectId('65686082d8f4d4f7789fa39c'),
#  'arrival_date_day_of_month': 26,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '71a1ecc3-99a4-474f-9b93-17d0574a8727',
#  'is_repeated_guest': 0,
#  'lead_time': 53,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-03'}
# {'_id': ObjectId('65686082d8f4d4f7789fa39d'),
#  'arrival_date_day_of_month': 26,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '3fe9b15a-a6e9-417d-b5e4-37df8b6117d7',
#  'is_repeated_guest': 0,
#  'lead_time': 179,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-10'}
# {'_id': ObjectId('65686082d8f4d4f7789fa3ab'),
#  'arrival_date_day_of_month': 27,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'ca6d1df8-5e82-4e63-ad15-a591a0c27bcc',
#  'is_repeated_guest': 0,
#  'lead_time': 200,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686082d8f4d4f7789fa3ba'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'c3cb1cc5-41d7-4442-97b9-bc7371abaf93',
#  'is_repeated_guest': 0,
#  'lead_time': 206,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686082d8f4d4f7789fa429'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Contract',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'ca792d90-0ea7-458b-905c-fc703ff13b27',
#  'is_repeated_guest': 0,
#  'lead_time': 171,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-07'}
# {'_id': ObjectId('65686082d8f4d4f7789fa42f'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'fe9cc097-9df7-482c-8d6d-c71d88d4532f',
#  'is_repeated_guest': 0,
#  'lead_time': 255,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-12'}
# {'_id': ObjectId('65686082d8f4d4f7789fa432'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Contract',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '99b1e042-fb23-4059-a79b-a74b3771350a',
#  'is_repeated_guest': 0,
#  'lead_time': 171,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-07'}
# {'_id': ObjectId('65686083d8f4d4f7789fd606'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'a081553a-3a45-4be4-b300-054a8f0e91e5',
#  'is_repeated_guest': 1,
#  'lead_time': 2,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-04-05'}
# {'_id': ObjectId('65686083d8f4d4f7789fe72a'),
#  'arrival_date_day_of_month': 1,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '84fcbd4d-547b-4e7f-b36a-f66888e31003',
#  'is_repeated_guest': 0,
#  'lead_time': 67,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-04-04'}
# {'_id': ObjectId('65686083d8f4d4f7789fe73a'),
#  'arrival_date_day_of_month': 1,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': 223.0,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '710f5bdd-09e0-4709-a8e8-1a7cf4afa995',
#  'is_repeated_guest': 0,
#  'lead_time': 2,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-04-01'}
# {'_id': ObjectId('65686083d8f4d4f7789fe77a'),
#  'arrival_date_day_of_month': 2,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '2dd34944-b8c0-4c07-9d0e-98d9493788bf',
#  'is_repeated_guest': 0,
#  'lead_time': 0,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-04'}
# {'_id': ObjectId('65686083d8f4d4f7789fe79f'),
#  'arrival_date_day_of_month': 2,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '93856f03-7e97-41cf-8c03-ef7c7182c06b',
#  'is_repeated_guest': 0,
#  'lead_time': 79,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-06'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7be'),
#  'arrival_date_day_of_month': 2,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '33eabe33-6a03-435f-94a7-f3cec75ca9d0',
#  'is_repeated_guest': 0,
#  'lead_time': 75,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-07'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7c0'),
#  'arrival_date_day_of_month': 6,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'ba56e083-c180-47af-bc3c-92b0229c55b9',
#  'is_repeated_guest': 0,
#  'lead_time': 0,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-04-07'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7cc'),
#  'arrival_date_day_of_month': 3,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'e21c0391-7e8e-4493-9637-f5e69db55114',
#  'is_repeated_guest': 0,
#  'lead_time': 8,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-08'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7cd'),
#  'arrival_date_day_of_month': 3,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '4423bb07-f663-43b6-b235-c071dec3c921',
#  'is_repeated_guest': 0,
#  'lead_time': 72,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-08'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7ce'),
#  'arrival_date_day_of_month': 1,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '94b1f4ec-d785-45f9-9f7d-bba7aa51f552',
#  'is_repeated_guest': 0,
#  'lead_time': 72,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-04-08'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7d0'),
#  'arrival_date_day_of_month': 3,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '8d666303-c0f8-4f07-a28e-ddcb99098704',
#  'is_repeated_guest': 0,
#  'lead_time': 88,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-08'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7d3'),
#  'arrival_date_day_of_month': 2,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 14,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '94e0a524-d6f1-4ffa-b37b-03c14033adf1',
#  'is_repeated_guest': 0,
#  'lead_time': 31,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-08'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7d5'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': 'd4c0cded-5636-480b-9998-d0c1f56e9b8e',
#  'is_repeated_guest': 0,
#  'lead_time': 48,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-08'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7db'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '861a80b9-aa6e-4edc-aea9-d58d3fc4fb93',
#  'is_repeated_guest': 0,
#  'lead_time': 74,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-09'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7dc'),
#  'arrival_date_day_of_month': 4,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '0ebc0774-a63e-4b4b-ae72-6194cddecf54',
#  'is_repeated_guest': 0,
#  'lead_time': 48,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-09'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7e7'),
#  'arrival_date_day_of_month': 6,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '1dac678c-d6d9-42d1-af62-3f3a6c7c8111',
#  'is_repeated_guest': 0,
#  'lead_time': 1,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-09'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7ee'),
#  'arrival_date_day_of_month': 7,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
#  'id_reservation': '89d25639-687d-4da3-8d65-175dd8d6051c',
#  'is_repeated_guest': 0,
#  'lead_time': 17,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-09'}
# {'_id': ObjectId('65686083d8f4d4f7789fe7f2'),
#  'arrival_date_day_of_month': 6,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 15,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'Resort Hotel',
# ...
#  'is_repeated_guest': 0,
#  'lead_time': 86,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-28'}
# {'_id': ObjectId('65686084d8f4d4f778a0e61d'),
#  'arrival_date_day_of_month': 27,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '8c5acef9-57bf-4413-92cd-1c2f5738f320',
#  'is_repeated_guest': 0,
#  'lead_time': 40,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-28'}
# {'_id': ObjectId('65686084d8f4d4f778a0e62b'),
#  'arrival_date_day_of_month': 24,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '0f02dd60-94f6-45b7-af7e-68b172f5fc1f',
#  'is_repeated_guest': 0,
#  'lead_time': 90,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-29'}
# {'_id': ObjectId('65686084d8f4d4f778a0e64b'),
#  'arrival_date_day_of_month': 24,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '75d4f509-8f35-4c1e-843f-f028dd2214f2',
#  'is_repeated_guest': 0,
#  'lead_time': 216,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-29'}
# {'_id': ObjectId('65686084d8f4d4f778a0e651'),
#  'arrival_date_day_of_month': 24,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '171a2174-e187-4482-af09-06a94a56dce9',
#  'is_repeated_guest': 0,
#  'lead_time': 186,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-29'}
# {'_id': ObjectId('65686084d8f4d4f778a0e657'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '95814603-465c-4afc-8158-62495578a0ed',
#  'is_repeated_guest': 0,
#  'lead_time': 3,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-29'}
# {'_id': ObjectId('65686084d8f4d4f778a0e65d'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'be6b0277-c309-40e1-b4b7-df99c35df00d',
#  'is_repeated_guest': 0,
#  'lead_time': 79,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-29'}
# {'_id': ObjectId('65686084d8f4d4f778a0e66d'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '2ba1347e-e67b-4ebf-8b90-ae2919a28bf1',
#  'is_repeated_guest': 0,
#  'lead_time': 0,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-29'}
# {'_id': ObjectId('65686084d8f4d4f778a0e686'),
#  'arrival_date_day_of_month': 27,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '0a3cf0b0-ffc8-47be-a822-b4c458b68aeb',
#  'is_repeated_guest': 0,
#  'lead_time': 30,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-04-30'}
# {'_id': ObjectId('65686084d8f4d4f778a0e694'),
#  'arrival_date_day_of_month': 23,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 17,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '7e7fc004-ebb3-4b1e-9a2f-22de880fff67',
#  'is_repeated_guest': 0,
#  'lead_time': 95,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-04-30'}
# {'_id': ObjectId('65686084d8f4d4f778a0e6a4'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 1,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'f0e16c05-f89e-43a1-a748-c938c7048a1d',
#  'is_repeated_guest': 0,
#  'lead_time': 41,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-01'}
# {'_id': ObjectId('65686084d8f4d4f778a0e6cc'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '44b67e63-7755-46c2-b4da-716abd062552',
#  'is_repeated_guest': 0,
#  'lead_time': 80,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-01'}
# {'_id': ObjectId('65686084d8f4d4f778a0e6e9'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '7c6d0183-a55d-401b-9511-543c40c75086',
#  'is_repeated_guest': 0,
#  'lead_time': 43,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-01'}
# {'_id': ObjectId('65686084d8f4d4f778a0e6f0'),
#  'arrival_date_day_of_month': 26,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'fb5d9dd6-93c8-44ff-9565-efe67ddcc660',
#  'is_repeated_guest': 0,
#  'lead_time': 86,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686084d8f4d4f778a0e6ff'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'c12f4129-e393-4bfa-bb82-2f0ce9ace145',
#  'is_repeated_guest': 0,
#  'lead_time': 61,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686084d8f4d4f778a0e717'),
#  'arrival_date_day_of_month': 29,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient-Party',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'f23aae10-0715-447f-accc-69c5ede6b642',
#  'is_repeated_guest': 0,
#  'lead_time': 64,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686084d8f4d4f778a0e71d'),
#  'arrival_date_day_of_month': 28,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '07e3ee36-0787-4d14-a837-ca2459bafa5b',
#  'is_repeated_guest': 0,
#  'lead_time': 9,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686084d8f4d4f778a0e71f'),
#  'arrival_date_day_of_month': 29,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '68a69bf5-e0dd-4a74-977e-f75e0185ab12',
#  'is_repeated_guest': 0,
#  'lead_time': 84,
#  'market_segment': 'Offline TA/TO',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686084d8f4d4f778a0e721'),
#  'arrival_date_day_of_month': 27,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '619256bb-6076-47c9-9609-07c6c6884f26',
#  'is_repeated_guest': 0,
#  'lead_time': 2,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-02'}
# {'_id': ObjectId('65686084d8f4d4f778a0e72c'),
#  'arrival_date_day_of_month': 29,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'fbff5e40-626f-4948-b305-fbb438cf69d6',
#  'is_repeated_guest': 0,
#  'lead_time': 24,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e746'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '3aca68a0-3a67-4b19-8134-5a3f7ab56cd5',
#  'is_repeated_guest': 0,
#  'lead_time': 35,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e747'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'fd56b766-1a18-4492-bd87-192af3e7f63c',
#  'is_repeated_guest': 0,
#  'lead_time': 35,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e74a'),
#  'arrival_date_day_of_month': 29,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'aab907f9-425b-4827-adee-eccddd3b9796',
#  'is_repeated_guest': 0,
#  'lead_time': 19,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e758'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'be165373-c6bc-40c1-8a04-97d3c2b1f276',
#  'is_repeated_guest': 0,
#  'lead_time': 109,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e759'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '07bfb92a-6819-455a-97b6-9489821e6da2',
#  'is_repeated_guest': 0,
#  'lead_time': 109,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e75a'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '367022a0-01d4-4828-b0b5-1df457458d63',
#  'is_repeated_guest': 0,
#  'lead_time': 109,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e75b'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'ce919474-6459-4b39-bb6f-792e4c5408b5',
#  'is_repeated_guest': 0,
#  'lead_time': 109,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e75c'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': '2d320fd3-72f5-49ca-a68e-be7c9fbcd407',
#  'is_repeated_guest': 0,
#  'lead_time': 108,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-03'}
# {'_id': ObjectId('65686084d8f4d4f778a0e7a5'),
#  'arrival_date_day_of_month': 29,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'City Hotel',
#  'id_reservation': 'd2b201b3-453b-4561-9422-cbd0c5254db2',
#  'is_repeated_guest': 0,
#  'lead_time': 226,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-05-04'}
# {'_id': ObjectId('65686084d8f4d4f778a0e7a6'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'TA/TO',
#  'hotel': 'City Hotel',
#  'id_reservation': 'e252fa5e-045a-4a83-b2f9-3171698416a8',
#  'is_repeated_guest': 0,
#  'lead_time': 24,
#  'market_segment': 'Online TA',
#  'reservation_status_date': '2016-05-04'}
# {'_id': ObjectId('65686084d8f4d4f778a0e7a7'),
#  'arrival_date_day_of_month': 30,
#  'arrival_date_month': 'April',
#  'arrival_date_week_number': 18,
#  'arrival_date_year': 2016,
#  'booking_changes': 0,
#  'company': nan,
#  'country': 'GBR',
#  'customer_type': 'Transient',
#  'days_in_waiting_list': 0,
#  'distribution_channel': 'Direct',
#  'hotel': 'City Hotel',
#  'id_reservation': 'e60a04f9-f2e4-4c26-b74f-09a298060a11',
#  'is_repeated_guest': 0,
#  'lead_time': 17,
#  'market_segment': 'Direct',
#  'reservation_status_date': '2016-05-04'}
# Não há documentos para serem exibidos em Reservas_Status.

# %%
import time
import pandas as pd
from pymongo import MongoClient
from pandas import json_normalize  # Importe a função json_normalize para achatar a estrutura

# Estabeleça uma conexão ao banco de dados MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Selecione o banco de dados
db = client['hotel_bookings']

# Registre o tempo de início
start_time = time.time()

# Consulta ao MongoDB
pipeline = [
    {
        "$group": {
            "_id": {
                "hotel": "$hotel",
                "country": "$country",
                "arrival_year": "$arrival_date_year",
                "arrival_month": "$arrival_date_month"
            },
            "total_reservas": {
                "$sum": 1
            }
        }
    },
    {
        "$match": {
            "total_reservas": {
                "$gt": 1000
            }
        }
    },
    {
        "$sort": {
            "total_reservas": -1
        }
    }
]

result = list(db.main_info.aggregate(pipeline))

# Achatar a estrutura do DataFrame
df_mongo = json_normalize(result)

# Registre o tempo de fim
end_time = time.time()
execution_time = end_time - start_time
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Exiba o DataFrame resultante
print(df_mongo)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
#     total_reservas _id.hotel _id.country  _id.arrival_year _id.arrival_month
# 0             2293   7 Hotel         PRT              2015         September
# 1             2206   7 Hotel         PRT              2015           October
# 2             1897   7 Hotel         PRT              2016              June
# 3             1552   7 Hotel         PRT              2017               May
# 4             1548   7 Hotel         PRT              2015            August
# 5             1531   7 Hotel         PRT              2016               May
# 6             1435   7 Hotel         PRT              2016           October
# 7             1426   7 Hotel         PRT              2016             April
# 8             1350   7 Hotel         PRT              2016         September
# 9             1341   7 Hotel         PRT              2017              June
# 10            1300   7 Hotel         PRT              2015              July
# 11            1200   7 Hotel         PRT              2016          November
# 12            1136   7 Hotel         PRT              2016          February
# 13            1132   7 Hotel         PRT              2017             April
# 14            1114   7 Hotel         PRT              2016             March
# 15            1006   7 Hotel         PRT              2017             March
# Tempo de execução: 0.16 segundos.

# %%
#Quais são os país que tiveram resevas alteradas suerior a 100 e, em que ano isto ocorreu? 
import time
import pandas as pd
from pymongo import MongoClient
from pandas import json_normalize  # Importe a função json_normalize para achatar a estrutura


# Estabeleça uma conexão ao banco de dados MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Selecione o banco de dados
db = client['hotel_bookings']

# Registre o tempo de início
start_time = time.time()

# Consulta ao MongoDB
pipeline = [
    {
        "$match": {
            "booking_changes": 0,
            "country": {"$ne": None}
        }
    },
    {
        "$group": {
            "_id": {
                "arrival_date_year": "$arrival_date_year",
                "country": "$country"
            },
            "total_reservas_alteradas": {
                "$sum": 1
            }
        }
    },
    {
        "$match": {
            "total_reservas_alteradas": {
                "$gt": 90
            }
        }
    },
    {
        "$sort": {
            "_id.arrival_date_year": 1
        }
    }
]

result = list(db.main_info.aggregate(pipeline))
df_mongo = json_normalize(result)
# Achatar a estrutura do DataFrame

# Renomear as colunas para corresponder à consulta SQL
df_mongo = df_mongo.rename(columns={"_id": "arrival_date_year_country", "total_reservas_alteradas": "total_reservas_alteradas"})

# Registre o tempo de fim
end_time = time.time()
execution_time = end_time - start_time

# Estas linhas, permitem remover o número total de linhas e colunas a serem exibidas 
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)

# Exiba o DataFrame resultante
print(df_mongo)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
#     total_reservas_alteradas  _id.arrival_date_year _id.country
# 0                        107                   2015         CHE
# 1                      11811                   2015         PRT
# 2                        161                   2015         NLD
# 3                       1126                   2015         FRA
# 4                        140                   2015         USA
# 5                       1136                   2015         GBR
# 6                        172                   2015         BEL
# 7                        459                   2015         DEU
# 8                        432                   2015         ITA
# 9                       1634                   2015         ESP
# 10                       123                   2015         BRA
# 11                       436                   2015         IRL
# 12                       110                   2015         NaN
# 13                       112                   2015          CN
# 14                       108                   2015         ISR
# 15                       113                   2015         SWE
# 16                       222                   2016         NOR
# 17                       439                   2016          CN
# 18                       868                   2016         BRA
# 19                      3331                   2016         ESP
# 20                       109                   2016         LUX
# 21                       544                   2016         AUT
# 22                      1230                   2016         IRL
# 23                      4368                   2016         GBR
# 24                       224                   2016         NaN
# 25                        92                   2016         HUN
# 26                      3226                   2016         DEU
# 27                      1572                   2016         ITA
# 28                       905                   2016         NLD
# 29                       205                   2016         RUS
# 30                       767                   2016         USA
# 31                       426                   2016         POL
# 32                       153                   2016         AGO
# 33                       206                   2016         FIN
# 34                       106                   2016         MAR
# 35                       960                   2016         BEL
# 36                       714                   2016         CHE
# 37                      4432                   2016         FRA
# 38                       150                   2016         DNK
# 39                       465                   2016         CHN
# 40                     19613                   2016         PRT
# 41                       413                   2016         SWE
# 42                        93                   2016         ARG
# 43                       229                   2016         ISR
# 44                       132                   2016         TUR
# 45                       147                   2016         AUS
# 46                       202                   2016         ROU
# 47                       229                   2017         RUS
# 48                      1110                   2017         ITA
# 49                       406                   2017         AUT
# 50                       752                   2017         USA
# 51                       314                   2017         SWE
# 52                       165                   2017         ROU
# 53                       223                   2017         ISR
# 54                       541                   2017          CN
# 55                       113                   2017         LUX
# 56                       191                   2017         AUS
# 57                       176                   2017         DNK
# 58                       637                   2017         CHE
# 59                      4360                   2017         GBR
# 60                       382                   2017         CHN
# 61                     11182                   2017         PRT
# 62                      3285                   2017         FRA
# 63                      2366                   2017         DEU
# 64                       662                   2017         NLD
# 65                        97                   2017         AGO
# 66                       870                   2017         BEL
# 67                       239                   2017         POL
# 68                       255                   2017         NOR
# 69                       851                   2017         BRA
# 70                      2152                   2017         ESP
# 71                       131                   2017         FIN
# 72                      1163                   2017         IRL
# Tempo de execução: 0.19 segundos.

# %%
import pandas as pd
import pymongo
from pymongo.errors import DuplicateKeyError
import uuid
import os

# Estabelecer conexão com o MongoDB
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = client['hotel_bookings']

# Nomes dos arquivos CSV e coleções MongoDB
csv_files = ['Tabela1.csv', 'Tabela2.csv', 'Tabela3.csv']
collection_names = ['main_info', 'reservas_status', 'stays_info']

def generate_id_reservation():
    return str(uuid.uuid4())

def insert_data_into_mongo(df, collection_name):
    documents = []
    for index, row in df.iterrows():
        id_reservation = generate_id_reservation()
        data = {
            "id_reservation": id_reservation,
            **row.to_dict()  # Inclua todas as colunas do DataFrame
        }
        documents.append(data)

    try:
        db[collection_name].insert_many(documents)
        print(f"Data for {collection_name} inserted successfully.")
    except DuplicateKeyError:
        print(f"Duplicate key error in {collection_name}. Skipping insertion.")

# Verificar se os arquivos CSV estão vazios
for csv_file, collection_name in zip(csv_files, collection_names):
    if os.path.getsize(csv_file) == 0:
        # Se o arquivo CSV estiver vazio, solicitar o arquivo JSON
        json_file = input(f"The CSV file {csv_file} is empty. Enter the path to the JSON file for data insertion: ")
        
        if os.path.exists(json_file) and os.path.getsize(json_file) > 0:
            # Ler o arquivo JSON em um DataFrame
            df_json = pd.read_json(json_file)

            # Inserir dados no MongoDB a partir do DataFrame JSON
            insert_data_into_mongo(df_json, collection_name)
            print("Data insertion completed.")
        else:
            print("The provided JSON file is invalid or empty. Exiting the program.")
            exit()
    else:
        # Se o arquivo CSV não estiver vazio, prosseguir com a inserção a partir do CSV
        df = pd.read_csv(csv_file)
        insert_data_into_mongo(df, collection_name)

print("Data insertion completed.")
# Out:
# Data for main_info inserted successfully.
# Data for reservas_status inserted successfully.
# Data for stays_info inserted successfully.
# Data insertion completed.

# %%
import pandas as pd
from pymongo import MongoClient
import time

# Estabeleça uma conexão com o banco de dados MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Selecione o banco de dados
db = client['hotel_bookings']

# Defina o tempo de início
start_time = time.time()

# Coleção principal
main_info = db['main_info']

# Consulta para calcular a média do número total de pedidos especiais para estadias em cada hotel
pipeline = [
    {
        "$lookup": {
            "from": "reservation_status",
            "localField": "id_reservation",
            "foreignField": "id_reservation",
            "as": "reservation_status"
        }
    },
    {
        "$unwind": "$reservation_status"
    },
    {
        "$lookup": {
            "from": "stays_info",
            "localField": "id_reservation",
            "foreignField": "id_reservation",
            "as": "stays_info"
        }
    },
    {
        "$unwind": "$stays_info"
    },
    {
        "$group": {
            "_id": "$hotel",
            "media_pedidos_especiais": {
                "$avg": "$stays_info.total_of_special_requests"
            }
        }
    }
]

# Execute a consulta e armazene o resultado em uma lista
result = list(main_info.aggregate(pipeline))

# Crie um DataFrame a partir do resultado da agregação
df_agregacao = pd.DataFrame(result)

# Exiba os resultados
for entry in result:
    print(f"Hotel: {entry['_id']}, Média de Pedidos Especiais: {entry['media_pedidos_especiais']}")

# Registre o tempo de execução
execution_time = time.time() - start_time

# Exiba o DataFrame resultante
print(df_agregacao)
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Tempo de execução: 5.31 segundos.

# %%
from pymongo import MongoClient

# Conecte-se ao seu banco de dados MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["hotel_bookings"]

# Acesse a coleção relevante
collection = db["reservas_status"]

# Execute a consulta agregada para encontrar reservas não canceladas
pipeline = [
    {
        "$lookup": {
            "from": "reservation_status_data",
            "localField": "id_reservation",
            "foreignField": "id_reservation",
            "as": "reservation_status",
        }
    },
    {
        "$match": {
            "reservation_status.is_canceled": {"$eq": 0}  # Reserva não cancelada
        }
    },
    {
        "$project": {
            "country": 1  # Apenas o campo do país
        }
    },
    {
        "$group": {
            "_id": "$country",
            "total_reservations": {"$sum": 1}
        }
    },
    {
        "$sort": {"total_reservations": -1}
    },
    {"$out": "output_collection"}  # Adicionando estágio para criar uma coleção de saída
]

result = list(collection.aggregate(pipeline))

# Imprima os países com o número de reservas não canceladas
for entry in result:
    print(f"País: {entry['_id']}, Reservas não canceladas: {entry['total_reservations']}")

# %%
from pymongo import MongoClient
import time

# Conectar ao banco de dados
client = MongoClient('localhost', 27017)
db = client.hotel_bookings
start_time = time.time()
# Atualizar o campo 'hotel' para "7 Hotel" onde 'hotel' é igual a "City Hotel"
filter_condition = {"hotel": " City Hotel"}
update_data = {"$set": {"hotel": "City Hotel"}}

result = db.main_info.update_many(filter_condition, update_data)
execution_time = time.time() - start_time
print(f"Total de documentos correspondentes: {result.matched_count}")
print(f"Total de documentos modificados: {result.modified_count}")
print(f"Tempo de execução: {execution_time:.2f} segundos.")
# Out:
# Total de documentos correspondentes: 0
# Total de documentos modificados: 0
# Tempo de execução: 0.17 segundos.

# %%
from pymongo import MongoClient
from datetime import datetime
from pymongo.errors import DuplicateKeyError

# Conectar ao banco de dados
client = MongoClient('localhost', 27017)
db = client.hotel_bookings

# Novo documento a ser inserido
novo_documento = {
    "id_reservation": 9999,
    "hotel": "Novo Hotel",
    "lead_time": 30,
    "arrival_date_year": 2023,
    "arrival_date_month": "Novembro",
    "arrival_date_week_number": 47,
    "arrival_date_day_of_month": 15,  # Substitua pelo valor desejado
    "country": "Portugal",
    "market_segment": 45,
    "distribution_channel": 478,
    "is_repeated_guest": 422,
    "booking_changes": 788,
    "days_in_waiting_list": 410,
    "company": "Tap",
    "customer_type": 6521,
    "reservation_status_date": datetime(2023, 11, 19)  # Utilize um objeto datetime
}

# Inserir o novo documento na coleção
try:
    result = db.Main_Info.insert_one(novo_documento)
    
    # Verificar se a inserção foi bem-sucedida
    if result.inserted_id:
        print(f"Novo documento inserido com sucesso. ID: {result.inserted_id}")

except DuplicateKeyError as e:
    print(f"Erro de chave duplicada em 'Main_Info': {e}")

except Exception as e:
    print(f"Falha ao inserir o documento. Erro: {e}")
# Out:
# Novo documento inserido com sucesso. ID: 6568765fd8f4d4f778a505ec
